# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\ANUSREE C R\Downloads\diabetes (1).csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
corr = df.corr()

plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True)
plt.show()

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.drop("SkinThickness", axis =1, inplace= True)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  Insulin   BMI  \
# 0              6      148             72        0  33.6
# 1              1       85             66        0  26.6
# 2              8      183             64        0  23.3
# 3              1       89             66       94  28.1
# 4              0      137             40      168  43.1
# ..           ...      ...            ...      ...   ...
# 763           10      101             76      180  32.9
# 764            2      122             70        0  36.8
# 765            5      121             72      112  26.2
# 766            1      126             60        0  30.1
# 767            1       93             70        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ...

# %% [markdown]
# ## histogram

# %%
# Set the style
sns.set(style="whitegrid")

# Create count plot (future-proof)
plt.figure(figsize=(6,4))
sns.countplot(x='Outcome', data=df, hue='Outcome', dodge=False, palette="Set2", legend=False)

# Add title and labels
plt.title("Number of Diabetic vs Non-Diabetic Cases", fontsize=14)
plt.xlabel("Outcome (0 = Non-Diabetic, 1 = Diabetic)", fontsize=12)
plt.ylabel("Count", fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(x='Outcome', y='Glucose', data=df, hue='Outcome', dodge=False, palette="Set2", legend=False)
plt.title("Glucose by Diabetes Outcome")
plt.xlabel("Outcome (0 = Non-Diabetic, 1 = Diabetic)")
plt.ylabel("Glucose")
plt.show()

# %% [markdown]
# ## Count Plot

# %%
#Set style
sns.set(style="whitegrid")

# List of numeric columns to plot
numeric_features = ['Glucose', 'BMI', 'Age']

# Create histograms
plt.figure(figsize=(15,4))
for i, feature in enumerate(numeric_features, 1):
    plt.subplot(1, 3, i)  # 1 row, 3 columns
    sns.histplot(df[feature], bins=20, kde=True, color='skyblue')
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
X= df.drop("Outcome", axis=1)

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  Insulin   BMI  \
# 0              6      148             72        0  33.6
# 1              1       85             66        0  26.6
# 2              8      183             64        0  23.3
# 3              1       89             66       94  28.1
# 4              0      137             40      168  43.1
# ..           ...      ...            ...      ...   ...
# 763           10      101             76      180  32.9
# 764            2      122             70        0  36.8
# 765            5      121             72      112  26.2
# 766            1      126             60        0  30.1
# 767            1       93             70        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# ...

# %%
y= df["Outcome"]# labels class

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(
    X, y, 
    test_size=0.2,      # 20% test data
    random_state=24)

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  Insulin   BMI  \
# 280            0      146             70        0  37.9
# 528            0      117             66      188  30.8
# 569            0      121             66      165  34.3
# 495            6      166             74        0  26.6
# 638            7       97             76       91  40.9
# ..           ...      ...            ...      ...   ...
# 145            0      102             75        0   0.0
# 401            6      137             61        0  24.2
# 343            5      122             86        0  34.7
# 192            7      159             66        0  30.4
# 418            1       83             68        0  18.2
#
#      DiabetesPedigreeFunction  Age
# 280                     0.334   28
# 528                     0.493   22
# 569                     0.203   33
# 495                     0.304   66
# 638                     0.871   32
# ..                        ...  ...
# 145                     0.572   21
# ...

# %%
y_train
# Out:
# 280    1
# 528    0
# 569    1
# 495    0
# 638    1
#       ..
# 145    0
# 401    0
# 343    0
# 192    1
# 418    0
# Name: Outcome, Length: 614, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=2000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.7402597402597403

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test,y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[87 11]
#  [29 27]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.89      0.81        98
#            1       0.71      0.48      0.57        56
#
#     accuracy                           0.74       154
#    macro avg       0.73      0.68      0.69       154
# weighted avg       0.74      0.74      0.73       154

# %%
from sklearn.naive_bayes import GaussianNB

model_G = GaussianNB()
model_G.fit(X_train, y_train)

y_pred = model_G.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7402597402597403

# %%
from sklearn.neighbors import KNeighborsClassifier

model_K = KNeighborsClassifier(n_neighbors=5)
model_K.fit(X_train, y_train)

y_pred = model_K.predict(X_test)
print("Accuracy:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6818181818181818

# %%
from sklearn.tree import DecisionTreeClassifier

model_D = DecisionTreeClassifier(random_state=42)
model_D.fit(X_train, y_train)

y_pred = model_D.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7597402597402597

# %%
from sklearn.ensemble import RandomForestClassifier

model_R = RandomForestClassifier(n_estimators=100, random_state=42)
model_R.fit(X_train, y_train)

y_pred = model_R.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7207792207792207

# %%
from sklearn.svm import SVC

model_S = SVC(kernel='rbf')
model_S.fit(X_train, y_train)

y_pred = model_S.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7077922077922078

# %%
from sklearn.ensemble import GradientBoostingClassifier

model_GR = GradientBoostingClassifier()
model_GR.fit(X_train, y_train)

y_pred = model_GR.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7207792207792207

# %%
import joblib
joblib.dump(model_D,'best_model_DIABETICS.pkl')
# Out:
# ['best_model_DIABETICS.pkl']
